# Epoch 77/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9850 - loss: 0.0482 - val_accuracy: 0.9300 - val_loss: 0.4031
# Epoch 78/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9876 - loss: 0.0417 - val_accuracy: 0.9231 - val_loss: 0.5147
# Epoch 79/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9910 - loss: 0.0401 - val_accuracy: 0.9193 - val_loss: 0.5467
# Epoch 80/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9863 - loss: 0.0466 - val_accuracy: 0.8937 - val_loss: 0.5251
# Epoch 81/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9779 - loss: 0.0887 - val_accuracy: 0.9150 - val_loss: 0.4141
# Epoch 82/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9910 - loss: 0.0332 - val_accuracy: 0.9157 - val_loss: 0.4455
# Epoch 83/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9862 - loss: 0.0452 - val_accuracy: 0.9198 - val_loss: 0.4041
# Epoch 84/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9896 - loss: 0.0344 - val_accuracy: 0.9074 - val_loss: 0.4936
# Epoch 85/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9842 - loss: 0.0579 - val_accuracy: 0.9026 - val_loss: 0.5652
# Epoch 86/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9872 - loss: 0.0469 - val_accuracy: 0.9154 - val_loss: 0.4985
# Epoch 87/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9748 - loss: 0.0894 - val_accuracy: 0.9209 - val_loss: 0.4003
# Epoch 88/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9892 - loss: 0.0402 - val_accuracy: 0.9187 - val_loss: 0.4669
# Epoch 89/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9919 - loss: 0.0293 - val_accuracy: 0.9167 - val_loss: 0.4425
# Epoch 90/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9918 - loss: 0.0302 - val_accuracy: 0.9044 - val_loss: 0.5324
# Epoch 91/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9902 - loss: 0.0329 - val_accuracy: 0.9274 - val_loss: 0.5275
# Epoch 92/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9967 - loss: 0.0141 - val_accuracy: 0.8985 - val_loss: 0.5465
# Epoch 93/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9784 - loss: 0.0747 - val_accuracy: 0.9141 - val_loss: 0.4452
# Epoch 94/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9885 - loss: 0.0417 - val_accuracy: 0.9191 - val_loss: 0.4744
# Epoch 95/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9869 - loss: 0.0470 - val_accuracy: 0.8987 - val_loss: 0.5772
# Epoch 96/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9897 - loss: 0.0388 - val_accuracy: 0.9144 - val_loss: 0.4160
# Epoch 97/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9878 - loss: 0.0488 - val_accuracy: 0.9081 - val_loss: 0.5591
# Epoch 98/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9861 - loss: 0.0450 - val_accuracy: 0.9144 - val_loss: 0.5403
# Epoch 99/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9910 - loss: 0.0331 - val_accuracy: 0.9089 - val_loss: 0.4404
# Epoch 100/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9747 - loss: 0.0934 - val_accuracy: 0.9231 - val_loss: 0.4595
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#
# Class                Accuracy
# AnnualCrop           0.92833
# Forest               0.95667
# HerbaceousVegetation 0.77667
# Highway              0.92000
# Industrial           0.95600
# Pasture              0.91250
# PermanentCrop        0.83800
# Residential          0.99167
# River                0.95800
# SeaLake              0.98667
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#           AnnualCrop    0.94889   0.92833   0.93850       600
#               Forest    0.97288   0.95667   0.96471       600
# HerbaceousVegetation    0.85192   0.77667   0.81255       600
#              Highway    0.93306   0.92000   0.92649       500
#           Industrial    0.95409   0.95600   0.95504       500
#              Pasture    0.85681   0.91250   0.88378       400
#        PermanentCrop    0.79962   0.83800   0.81836       500
#          Residential    0.90979   0.99167   0.94896       600
#                River    0.98763   0.95800   0.97259       500
#              SeaLake    0.99831   0.98667   0.99246       600
#
#             accuracy                        0.92315      5400
#            macro avg    0.92130   0.92245   0.92134      5400
#         weighted avg    0.92389   0.92315   0.92297      5400

# %% [markdown]
# **BASE PAPER METHOD-NIR-RED-GREEM**

# %%
import os
import numpy as np
import tensorflow as tf
import rasterio
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# ----------- Parameters -----------
data_dir = "/kaggle/input/all-band-eurosat/tif"
img_size = (64, 64)
selected_channels = [7, 3, 2]  
batch_size = 64
epochs = 100

# ----------- Load Data -----------
def load_tif_images(base_dir, img_size=(64, 64), selected_channels=[7, 3, 2]):
    images, labels = [], []
    class_names = sorted([d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))])
    
    for label in class_names:
        class_dir = os.path.join(base_dir, label)
        for fname in os.listdir(class_dir):
            if fname.endswith(".tif"):
                path = os.path.join(class_dir, fname)
                with rasterio.open(path) as src:
                    img = src.read(selected_channels)  # shape: (3, H, W)
                    img = np.moveaxis(img, 0, -1)      # shape: (H, W, 3)
                    img = img.astype(np.float32) / 255.0
                    img = tf.image.resize(img, img_size).numpy()
                    images.append(img)
                    labels.append(label)

    return np.array(images), np.array(labels), class_names

X, y, class_names = load_tif_images(data_dir, img_size, selected_channels)

# ----------- Encode Labels -----------
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_onehot = tf.keras.utils.to_categorical(y_encoded)

# ----------- Train-Test Split -----------
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, stratify=y_encoded, random_state=42)

# ----------- Dataset API -----------
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1000).batch(batch_size)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size)

# ----------- CNN Model -----------
def create_custom_cnn(num_classes):
    inputs = tf.keras.Input(shape=(64, 64, 3))

    # Conv Block 1
    x = tf.keras.layers.Conv2D(16, 3, padding='same', activation='gelu')(inputs)
    x = tf.keras.layers.Conv2D(16, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)

    # Conv Block 2
    x = tf.keras.layers.Conv2D(32, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.Conv2D(32, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)

    # Conv Block 3
    x = tf.keras.layers.Conv2D(64, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.Conv2D(64, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)

    # Conv Block 4
    x = tf.keras.layers.Conv2D(128, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.Conv2D(128, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)

    # Conv Block 5
    x = tf.keras.layers.Conv2D(256, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.Conv2D(256, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)



# %%
import os
import numpy as np
import tensorflow as tf
import rasterio
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# ----------- Parameters -----------
data_dir = "/kaggle/input/all-band-eurosat/tif"
img_size = (64, 64)
batch_size = 64
epochs = 100

# ----------- Load Data with NDVI, NDBI, NDWI -----------
def load_indices_images(base_dir, img_size=(64, 64)):
    images, labels = [], []
    class_names = sorted([d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))])

    for label in class_names:
        class_dir = os.path.join(base_dir, label)
        for fname in os.listdir(class_dir):
            if fname.endswith(".tif"):
                path = os.path.join(class_dir, fname)
                with rasterio.open(path) as src:
                    nir = src.read(7).astype(np.float32)
                    red = src.read(3).astype(np.float32)
                    green = src.read(2).astype(np.float32)
                    swir = src.read(12).astype(np.float32)

                    # Compute indices with small value added to denominator to avoid division by zero
                    ndvi = (nir - red) / (nir + red + 1e-6)
                    ndbi = (swir - nir) / (swir + nir + 1e-6)
                    ndwi = (green - nir) / (green + nir + 1e-6)

                    # Stack into a 3-channel image
                    img = np.stack([ndvi, ndbi, ndwi], axis=-1)
                    img = tf.image.resize(img, img_size).numpy()
                    images.append(img)
                    labels.append(label)

    return np.array(images), np.array(labels), class_names

X, y, class_names = load_indices_images(data_dir, img_size)

# ----------- Encode Labels -----------
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_onehot = tf.keras.utils.to_categorical(y_encoded)

# ----------- Train-Test Split -----------
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, stratify=y_encoded, random_state=42)

# ----------- Dataset API -----------
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1000).batch(batch_size)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size)

# ----------- CNN Model (unchanged) -----------
def create_custom_cnn(num_classes):
    inputs = tf.keras.Input(shape=(64, 64, 3))

    x = tf.keras.layers.Conv2D(16, 3, padding='same', activation='gelu')(inputs)
    x = tf.keras.layers.Conv2D(16, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)

    x = tf.keras.layers.Conv2D(32, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.Conv2D(32, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)

    x = tf.keras.layers.Conv2D(64, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.Conv2D(64, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)

    x = tf.keras.layers.Conv2D(128, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.Conv2D(128, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)

    x = tf.keras.layers.Conv2D(256, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.Conv2D(256, 3, padding='same', activation='gelu')(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)

    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(512, activation='gelu')(x)
    x = tf.keras.layers.Dense(256, activation='gelu')(x)
    x = tf.keras.layers.Dense(128, activation='gelu')(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# ----------- Train Model -----------
model = create_custom_cnn(num_classes=len(class_names))
model.summary()
model.fit(train_ds, validation_data=test_ds, epochs=epochs)

# ----------- Evaluation -----------
y_pred_probs = model.predict(test_ds)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(np.vstack([y for _, y in test_ds]), axis=1)

cm = confusion_matrix(y_true, y_pred)
per_class_acc = cm.diagonal() / cm.sum(axis=1)

print(f"\n{'Class':<20} {'Accuracy':<10}")
for i, label in enumerate(class_names):
    print(f"{label:<20} {per_class_acc[i]:.5f}")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=5))
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 64, 64, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 64, 64, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_24 (Conv2D)                   │ (None, 64, 64, 16)          │           2,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_23 (MaxPooling2D)      │ (None, 32, 32, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_25 (Conv2D)                   │ (None, 32, 32, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_26 (Conv2D)                   │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_24 (MaxPooling2D)      │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_27 (Conv2D)                   │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_28 (Conv2D)                   │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_25 (MaxPooling2D)      │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_29 (Conv2D)                   │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_30 (Conv2D)                   │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_26 (MaxPooling2D)      │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_31 (Conv2D)                   │ (None, 4, 4, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_32 (Conv2D)                   │ (None, 4, 4, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_27 (MaxPooling2D)      │ (None, 2, 2, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,869,082 (7.13 MB)
#  Trainable params: 1,869,082 (7.13 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 18s 27ms/step - accuracy: 0.3486 - loss: 1.7083 - val_accuracy: 0.6374 - val_loss: 0.9792
# Epoch 2/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6666 - loss: 0.8689 - val_accuracy: 0.7346 - val_loss: 0.7178
# Epoch 3/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7721 - loss: 0.6280 - val_accuracy: 0.7724 - val_loss: 0.6175
# Epoch 4/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8197 - loss: 0.4968 - val_accuracy: 0.7843 - val_loss: 0.6178
# Epoch 5/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8450 - loss: 0.4292 - val_accuracy: 0.8278 - val_loss: 0.4862
# Epoch 6/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8654 - loss: 0.3708 - val_accuracy: 0.8422 - val_loss: 0.4263
# Epoch 7/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8834 - loss: 0.3264 - val_accuracy: 0.8600 - val_loss: 0.3935
# Epoch 8/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9021 - loss: 0.2750 - val_accuracy: 0.8685 - val_loss: 0.4026
# Epoch 9/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9127 - loss: 0.2508 - val_accuracy: 0.8819 - val_loss: 0.3510
# Epoch 10/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9257 - loss: 0.2141 - val_accuracy: 0.8887 - val_loss: 0.3249
# Epoch 11/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9328 - loss: 0.1894 - val_accuracy: 0.8965 - val_loss: 0.3154
# Epoch 12/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9469 - loss: 0.1484 - val_accuracy: 0.8857 - val_loss: 0.3667
# Epoch 13/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9453 - loss: 0.1557 - val_accuracy: 0.8604 - val_loss: 0.4555
# Epoch 14/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9533 - loss: 0.1292 - val_accuracy: 0.8944 - val_loss: 0.3733
# Epoch 15/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9540 - loss: 0.1307 - val_accuracy: 0.8804 - val_loss: 0.4406
# Epoch 16/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9612 - loss: 0.1152 - val_accuracy: 0.8815 - val_loss: 0.4315
# Epoch 17/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9647 - loss: 0.1039 - val_accuracy: 0.8944 - val_loss: 0.3916
# Epoch 18/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9731 - loss: 0.0793 - val_accuracy: 0.8711 - val_loss: 0.5029
# Epoch 19/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9679 - loss: 0.0956 - val_accuracy: 0.8994 - val_loss: 0.3991
# Epoch 20/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9722 - loss: 0.0845 - val_accuracy: 0.8837 - val_loss: 0.5123
# Epoch 21/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9724 - loss: 0.0827 - val_accuracy: 0.8813 - val_loss: 0.4371
# Epoch 22/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9761 - loss: 0.0708 - val_accuracy: 0.8928 - val_loss: 0.4254
# Epoch 23/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#
# Class                Accuracy
# AnnualCrop           0.91833
# Forest               0.94000
# HerbaceousVegetation 0.81000
# Highway              0.90400
# Industrial           0.98400
# Pasture              0.78250
# PermanentCrop        0.69400
# Residential          0.95500
# River                0.95200
# SeaLake              0.99833
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#           AnnualCrop    0.87184   0.91833   0.89448       600
#               Forest    0.91410   0.94000   0.92687       600
# HerbaceousVegetation    0.81000   0.81000   0.81000       600
#              Highway    0.90400   0.90400   0.90400       500
#           Industrial    0.89292   0.98400   0.93625       500
#              Pasture    0.83245   0.78250   0.80670       400
#        PermanentCrop    0.82227   0.69400   0.75271       500
#          Residential    0.93019   0.95500   0.94243       600
#                River    0.98755   0.95200   0.96945       500
#              SeaLake    0.99172   0.99833   0.99502       600
#
#             accuracy                        0.89870      5400
#            macro avg    0.89570   0.89382   0.89379      5400
#         weighted avg    0.89760   0.89870   0.89725      5400

# %% [markdown]
# ***SATRAT OF PROPOSED METHODOLOGY***

# %% [markdown]
# **PROPOSED --NIR-RED--GREEN**

# %%
import os
import numpy as np
import tensorflow as tf
import rasterio
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# ----------- Parameters -----------
data_dir = "/kaggle/input/all-band-eurosat/tif"
img_size = (64, 64)
selected_channels = [7, 3, 2] 
batch_size = 64
epochs = 100

# ----------- Load Data -----------
def load_tif_images(base_dir, img_size=(64, 64), selected_channels=[7, 3, 2]):
    images, labels = [], []
    class_names = sorted([d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))])
    
    for label in class_names:
        class_dir = os.path.join(base_dir, label)
        for fname in os.listdir(class_dir):
            if fname.endswith(".tif"):
                path = os.path.join(class_dir, fname)
                with rasterio.open(path) as src:
                    img = src.read(selected_channels)  # shape: (3, H, W)
                    img = np.moveaxis(img, 0, -1)      # shape: (H, W, 3)
                    img = img.astype(np.float32) / 255.0
                    img = tf.image.resize(img, img_size).numpy()
                    images.append(img)
                    labels.append(label)

    return np.array(images), np.array(labels), class_names

X, y, class_names = load_tif_images(data_dir, img_size, selected_channels)

# ----------- Encode Labels -----------
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_onehot = tf.keras.utils.to_categorical(y_encoded)

# ----------- Train-Test Split -----------
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, stratify=y_encoded, random_state=42)

# ----------- Dataset API -----------
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1000).batch(batch_size)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size)

# ----------- CNN Model: Color-Specific -----------
def create_color_specific_model(num_classes):
    """CNN Model with Color-Specific Convolutions"""
    inputs = tf.keras.Input(shape=(64, 64, 3))
    
    channel1 = inputs[:, :, :, 0:1]  # First selected channel (e.g., 7)
    channel2 = inputs[:, :, :, 1:2]  # Second selected channel (e.g., 3)
    channel3 = inputs[:, :, :, 2:3]  # Third selected channel (e.g., 2)
    
    red_conv = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(channel1)
    red_pool = tf.keras.layers.MaxPooling2D(2,2)(red_conv)
    
    green_conv = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(channel2)
    green_pool = tf.keras.layers.MaxPooling2D(2,2)(green_conv)
    
    blue_conv = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(channel3)
    blue_pool = tf.keras.layers.MaxPooling2D(2,2)(blue_conv)
    
    combined = tf.keras.layers.Concatenate()([red_pool, green_pool, blue_pool])
    
    conv1 = tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same')(combined)
    pool1 = tf.keras.layers.MaxPooling2D(2,2)(conv1)
    
    conv2 = tf.keras.layers.Conv2D(128, (3,3), activation='relu', padding='same')(pool1)
    pool2 = tf.keras.layers.MaxPooling2D(2,2)(conv2)
    
    flatten = tf.keras.layers.Flatten()(pool2)
    dense1 = tf.keras.layers.Dense(128, activation='relu')(flatten)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(dense1)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.AdamW(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# ----------- Train Model -----------
model = create_color_specific_model(num_classes=len(class_names))
model.summary()
model.fit(train_ds, validation_data=test_ds, epochs=epochs)

# ----------- Evaluation -----------
y_pred_probs = model.predict(test_ds)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(np.vstack([y for _, y in test_ds]), axis=1)

cm = confusion_matrix(y_true, y_pred)
per_class_acc = cm.diagonal() / cm.sum(axis=1)

print(f"\n{'Class':<20} {'Accuracy':<10}")
for i, label in enumerate(class_names):
    print(f"{label:<20} {per_class_acc[i]:.5f}")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=5))
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6             │ (None, 64, 64, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_3 (GetItem)      │ (None, 64, 64, 1)      │              0 │ input_layer_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_4 (GetItem)      │ (None, 64, 64, 1)      │              0 │ input_layer_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_5 (GetItem)      │ (None, 64, 64, 1)      │              0 │ input_layer_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_43 (Conv2D)        │ (None, 64, 64, 32)     │            320 │ get_item_3[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_44 (Conv2D)        │ (None, 64, 64, 32)     │            320 │ get_item_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_45 (Conv2D)        │ (None, 64, 64, 32)     │            320 │ get_item_5[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_28          │ (None, 32, 32, 32)     │              0 │ conv2d_43[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_29          │ (None, 32, 32, 32)     │              0 │ conv2d_44[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_30          │ (None, 32, 32, 32)     │              0 │ conv2d_45[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 32, 32, 96)     │              0 │ max_pooling2d_28[0][0… │
# │ (Concatenate)             │                        │                │ max_pooling2d_29[0][0… │
# │                           │                        │                │ max_pooling2d_30[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_46 (Conv2D)        │ (None, 32, 32, 64)     │         55,360 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_31          │ (None, 16, 16, 64)     │              0 │ conv2d_46[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_47 (Conv2D)        │ (None, 16, 16, 128)    │         73,856 │ max_pooling2d_31[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_32          │ (None, 8, 8, 128)      │              0 │ conv2d_47[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_4 (Flatten)       │ (None, 8192)           │              0 │ max_pooling2d_32[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_36 (Dense)          │ (None, 128)            │      1,048,704 │ flatten_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_37 (Dense)          │ (None, 10)             │          1,290 │ dense_36[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,180,170 (4.50 MB)
#  Trainable params: 1,180,170 (4.50 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0
# Epoch 81/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 3.6953e-06 - val_accuracy: 0.9139 - val_loss: 0.6771
# Epoch 82/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 3.1170e-06 - val_accuracy: 0.9146 - val_loss: 0.6832
# Epoch 83/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 2.6442e-06 - val_accuracy: 0.9154 - val_loss: 0.6902
# Epoch 84/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 2.2958e-06 - val_accuracy: 0.9154 - val_loss: 0.6958
# Epoch 85/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.8589e-06 - val_accuracy: 0.9152 - val_loss: 0.6986
# Epoch 86/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.5781e-06 - val_accuracy: 0.9156 - val_loss: 0.7054
# Epoch 87/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.3831e-06 - val_accuracy: 0.9154 - val_loss: 0.7128
# Epoch 88/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.1179e-06 - val_accuracy: 0.9159 - val_loss: 0.7206
# Epoch 89/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 9.4283e-07 - val_accuracy: 0.9159 - val_loss: 0.7269
# Epoch 90/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 8.0334e-07 - val_accuracy: 0.9169 - val_loss: 0.7290
# Epoch 91/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 7.0286e-07 - val_accuracy: 0.9174 - val_loss: 0.7356
# Epoch 92/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 5.7326e-07 - val_accuracy: 0.9172 - val_loss: 0.7428
# Epoch 93/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 5.3467e-07 - val_accuracy: 0.9178 - val_loss: 0.7503
# Epoch 94/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 3.9358e-07 - val_accuracy: 0.9169 - val_loss: 0.7554
# Epoch 95/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 3.5347e-07 - val_accuracy: 0.9178 - val_loss: 0.7589
# Epoch 96/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 3.0043e-07 - val_accuracy: 0.9180 - val_loss: 0.7680
# Epoch 97/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 2.4800e-07 - val_accuracy: 0.9181 - val_loss: 0.7706
# Epoch 98/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 2.1242e-07 - val_accuracy: 0.9170 - val_loss: 0.7778
# Epoch 99/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.7700e-07 - val_accuracy: 0.9167 - val_loss: 0.7851
# Epoch 100/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.5238e-07 - val_accuracy: 0.9170 - val_loss: 0.7890
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# Class                Accuracy
# AnnualCrop           0.87000
# Forest               0.96667
# HerbaceousVegetation 0.84500
# Highway              0.88000
# Industrial           0.96800
# Pasture              0.87750
# PermanentCrop        0.82000
# Residential          0.97167
# River                0.95400
# SeaLake              0.99667
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#           AnnualCrop    0.90311   0.87000   0.88625       600
#               Forest    0.95238   0.96667   0.95947       600
# HerbaceousVegetation    0.83251   0.84500   0.83871       600
#              Highway    0.89796   0.88000   0.88889       500
#           Industrial    0.95276   0.96800   0.96032       500
#              Pasture    0.88861   0.87750   0.88302       400
#        PermanentCrop    0.79767   0.82000   0.80868       500
#          Residential    0.96364   0.97167   0.96763       600
#                River    0.96951   0.95400   0.96169       500
#              SeaLake    0.99667   0.99667   0.99667       600
#
#             accuracy                        0.91704      5400
#            macro avg    0.91548   0.91495   0.91513      5400
#         weighted avg    0.91729   0.91704   0.91708      5400

# %% [markdown]
# **PROPOSED SE BASED NIR-RED-GREEN MODEL**

# %%
import os
import numpy as np
import tensorflow as tf
import rasterio
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# --- Parameters ---
data_dir = "/kaggle/input/all-band-eurosat/tif"
img_size = (64, 64)
selected_channels = [7, 3, 2]
batch_size = 64
epochs = 100

# --- Load Data ---
def load_tif_images(base_dir, img_size=(64, 64), selected_channels=[7, 3, 2]):
    images, labels = [], []
    class_names = sorted([d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))])
    
    for label in class_names:
        class_dir = os.path.join(base_dir, label)
        for fname in os.listdir(class_dir):
            if fname.endswith(".tif"):
                path = os.path.join(class_dir, fname)
                with rasterio.open(path) as src:
                    img = src.read(selected_channels)  # (3, H, W)
                    img = np.moveaxis(img, 0, -1)      # (H, W, 3)
                    img = img.astype(np.float32) / 255.0
                    img = tf.image.resize(img, img_size).numpy()
                    images.append(img)
                    labels.append(label)

    return np.array(images), np.array(labels), class_names

X, y, class_names = load_tif_images(data_dir, img_size, selected_channels)

# --- Encode Labels ---
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_onehot = tf.keras.utils.to_categorical(y_encoded)

# --- Split ---
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, stratify=y_encoded, random_state=42)

# --- TF Datasets ---
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1000).batch(batch_size)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size)

# --- SE Block ---
def se_block(input_tensor, reduction=8):
    filters = input_tensor.shape[-1]
    se = tf.keras.layers.GlobalAveragePooling2D()(input_tensor)
    se = tf.keras.layers.Dense(filters // reduction, activation='relu')(se)
    se = tf.keras.layers.Dense(filters, activation='sigmoid')(se)
    se = tf.keras.layers.Reshape((1, 1, filters))(se)
    return tf.keras.layers.Multiply()([input_tensor, se])

# --- Model ---
def create_color_specific_model(num_classes):
    inputs = tf.keras.Input(shape=(64, 64, 3))
    
    channel1 = inputs[:, :, :, 0:1]
    channel2 = inputs[:, :, :, 1:2]
    channel3 = inputs[:, :, :, 2:3]
    
    red_conv = tf.keras.layers.Conv2D(24, (3,3), activation='relu', padding='same')(channel1)
    red_se = se_block(red_conv)
    red_pool = tf.keras.layers.MaxPooling2D(2,2)(red_se)
    
    green_conv = tf.keras.layers.Conv2D(24, (3,3), activation='relu', padding='same')(channel2)
    green_se = se_block(green_conv)
    green_pool = tf.keras.layers.MaxPooling2D(2,2)(green_se)
    
    blue_conv = tf.keras.layers.Conv2D(24, (3,3), activation='relu', padding='same')(channel3)
    blue_se = se_block(blue_conv)
    blue_pool = tf.keras.layers.MaxPooling2D(2,2)(blue_se)
    
    combined = tf.keras.layers.Concatenate()([red_pool, green_pool, blue_pool])
    
    conv1 = tf.keras.layers.Conv2D(48, (3,3), activation='relu', padding='same')(combined)
    conv1_se = se_block(conv1)
    pool1 = tf.keras.layers.MaxPooling2D(2,2)(conv1_se)
    
    conv2 = tf.keras.layers.Conv2D(96, (3,3), activation='relu', padding='same')(pool1)
    conv2_se = se_block(conv2)
    pool2 = tf.keras.layers.MaxPooling2D(2,2)(conv2_se)
    
    flatten = tf.keras.layers.Flatten()(pool2)
    dense1 = tf.keras.layers.Dense(192, activation='relu')(flatten)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(dense1)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.AdamW(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# --- Train ---
model = create_color_specific_model(num_classes=len(class_names))
model.summary()
model.fit(train_ds, validation_data=test_ds, epochs=epochs)

# --- Evaluation ---
y_pred_probs = model.predict(test_ds)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(np.vstack([y for _, y in test_ds]), axis=1)

cm = confusion_matrix(y_true, y_pred)
per_class_acc = cm.diagonal() / cm.sum(axis=1)

print(f"\n{'Class':<20} {'Accuracy':<10}")
for i, label in enumerate(class_names):
    print(f"{label:<20} {per_class_acc[i]:.5f}")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=5))
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6             │ (None, 64, 64, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_28 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_29 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_30 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_48 (Conv2D)        │ (None, 64, 64, 24)     │            240 │ get_item_28[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_49 (Conv2D)        │ (None, 64, 64, 24)     │            240 │ get_item_29[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_50 (Conv2D)        │ (None, 64, 64, 24)     │            240 │ get_item_30[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 24)             │              0 │ conv2d_48[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 24)             │              0 │ conv2d_49[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 24)             │              0 │ conv2d_50[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_34 (Dense)          │ (None, 3)              │             75 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_36 (Dense)          │ (None, 3)              │             75 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_38 (Dense)          │ (None, 3)              │             75 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_35 (Dense)          │ (None, 24)             │             96 │ dense_34[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_37 (Dense)          │ (None, 24)             │             96 │ dense_36[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_39 (Dense)          │ (None, 24)             │             96 │ dense_38[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_10 (Reshape)      │ (None, 1, 1, 24)       │              0 │ dense_35[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_11 (Reshape)      │ (None, 1, 1, 24)       │              0 │ dense_37[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_12 (Reshape)      │ (None, 1, 1, 24)       │              0 │ dense_39[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_10 (Multiply)    │ (None, 64, 64, 24)     │              0 │ conv2d_48[0][0],       │
# │                           │                        │                │ reshape_10[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_11 (Multiply)    │ (None, 64, 64, 24)     │              0 │ conv2d_49[0][0],       │
# │                           │                        │                │ reshape_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_12 (Multiply)    │ (None, 64, 64, 24)     │              0 │ conv2d_50[0][0],       │
# │                           │                        │                │ reshape_12[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_43          │ (None, 32, 32, 24)     │              0 │ multiply_10[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_44          │ (None, 32, 32, 24)     │              0 │ multiply_11[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_45          │ (None, 32, 32, 24)     │              0 │ multiply_12[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 32, 32, 72)     │              0 │ max_pooling2d_43[0][0… │
# │ (Concatenate)             │                        │                │ max_pooling2d_44[0][0… │
# │                           │                        │                │ max_pooling2d_45[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_51 (Conv2D)        │ (None, 32, 32, 48)     │         31,152 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 48)             │              0 │ conv2d_51[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_40 (Dense)          │ (None, 6)              │            294 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_41 (Dense)          │ (None, 48)             │            336 │ dense_40[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_13 (Reshape)      │ (None, 1, 1, 48)       │              0 │ dense_41[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_13 (Multiply)    │ (None, 32, 32, 48)     │              0 │ conv2d_51[0][0],       │
# │                           │                        │                │ reshape_13[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_46          │ (None, 16, 16, 48)     │              0 │ multiply_13[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_52 (Conv2D)        │ (None, 16, 16, 96)     │         41,568 │ max_pooling2d_46[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 96)             │              0 │ conv2d_52[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_42 (Dense)          │ (None, 12)             │          1,164 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_43 (Dense)          │ (None, 96)             │          1,248 │ dense_42[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_14 (Reshape)      │ (None, 1, 1, 96)       │              0 │ dense_43[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_14 (Multiply)    │ (None, 16, 16, 96)     │              0 │ conv2d_52[0][0],       │
# │                           │                        │                │ reshape_14[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_47          │ (None, 8, 8, 96)       │              0 │ multiply_14[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_6 (Flatten)       │ (None, 6144)           │              0 │ max_pooling2d_47[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_44 (Dense)          │ (None, 192)            │      1,179,840 │ flatten_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_45 (Dense)          │ (None, 10)             │          1,930 │ dense_44[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,258,765 (4.80 MB)
#  Trainable params: 1,258,765 (4.80 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 17s 25ms/step - accuracy: 0.5170 - loss: 1.2882 - val_accuracy: 0.7170 - val_loss: 0.7614
# Epoch 2/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.
# Epoch 84/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 6.5877e-07 - val_accuracy: 0.9126 - val_loss: 0.7956
# Epoch 85/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 5.5604e-07 - val_accuracy: 0.9135 - val_loss: 0.8060
# Epoch 86/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 4.6816e-07 - val_accuracy: 0.9128 - val_loss: 0.8148
# Epoch 87/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 3.7792e-07 - val_accuracy: 0.9126 - val_loss: 0.8224
# Epoch 88/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 3.2424e-07 - val_accuracy: 0.9131 - val_loss: 0.8319
# Epoch 89/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.6712e-07 - val_accuracy: 0.9130 - val_loss: 0.8402
# Epoch 90/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.2551e-07 - val_accuracy: 0.9137 - val_loss: 0.8481
# Epoch 91/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.8889e-07 - val_accuracy: 0.9139 - val_loss: 0.8581
# Epoch 92/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.5553e-07 - val_accuracy: 0.9133 - val_loss: 0.8657
# Epoch 93/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.3296e-07 - val_accuracy: 0.9139 - val_loss: 0.8760
# Epoch 94/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.0988e-07 - val_accuracy: 0.9133 - val_loss: 0.8848
# Epoch 95/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 9.1386e-08 - val_accuracy: 0.9131 - val_loss: 0.8940
# Epoch 96/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 7.6970e-08 - val_accuracy: 0.9135 - val_loss: 0.9026
# Epoch 97/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 6.2214e-08 - val_accuracy: 0.9139 - val_loss: 0.9110
# Epoch 98/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 5.3722e-08 - val_accuracy: 0.9137 - val_loss: 0.9203
# Epoch 99/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 4.4355e-08 - val_accuracy: 0.9137 - val_loss: 0.9299
# Epoch 100/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 3.7587e-08 - val_accuracy: 0.9141 - val_loss: 0.9410
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
#
# Class                Accuracy
# AnnualCrop           0.88167
# Forest               0.96500
# HerbaceousVegetation 0.83667
# Highway              0.87800
# Industrial           0.97000
# Pasture              0.85750
# PermanentCrop        0.80800
# Residential          0.96167
# River                0.96400
# SeaLake              0.99333
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#           AnnualCrop    0.90427   0.88167   0.89283       600
#               Forest    0.94146   0.96500   0.95309       600
# HerbaceousVegetation    0.83667   0.83667   0.83667       600
#              Highway    0.91079   0.87800   0.89409       500
#           Industrial    0.93629   0.97000   0.95285       500
#              Pasture    0.87277   0.85750   0.86507       400
#        PermanentCrop    0.78295   0.80800   0.79528       500
#          Residential    0.96488   0.96167   0.96327       600
#                River    0.97967   0.96400   0.97177       500
#              SeaLake    0.99168   0.99333   0.99251       600
#
#             accuracy                        0.91407      5400
#            macro avg    0.91214   0.91158   0.91174      5400
#         weighted avg    0.91432   0.91407   0.91408      5400

# %% [markdown]
# **PROPOSED-SWIR-NIR-RED**

# %%
import os
import numpy as np
import tensorflow as tf
import rasterio
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# ----------- Parameters -----------
data_dir = "/kaggle/input/all-band-eurosat/tif"
img_size = (64, 64)
selected_channels = [12, 7, 3] 
batch_size = 64
epochs = 100

# ----------- Load Data -----------
def load_tif_images(base_dir, img_size=(64, 64), selected_channels=[12, 7, 3]):
    images, labels = [], []
    class_names = sorted([d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))])
    
    for label in class_names:
        class_dir = os.path.join(base_dir, label)
        for fname in os.listdir(class_dir):
            if fname.endswith(".tif"):
                path = os.path.join(class_dir, fname)
                with rasterio.open(path) as src:
                    img = src.read(selected_channels)  # shape: (3, H, W)
                    img = np.moveaxis(img, 0, -1)      # shape: (H, W, 3)
                    img = img.astype(np.float32) / 255.0
                    img = tf.image.resize(img, img_size).numpy()
                    images.append(img)
                    labels.append(label)

    return np.array(images), np.array(labels), class_names

X, y, class_names = load_tif_images(data_dir, img_size, selected_channels)

# ----------- Encode Labels -----------
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_onehot = tf.keras.utils.to_categorical(y_encoded)

# ----------- Train-Test Split -----------
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, stratify=y_encoded, random_state=42)

# ----------- Dataset API -----------
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1000).batch(batch_size)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size)

# ----------- CNN Model: Color-Specific -----------
def create_color_specific_model(num_classes):
    """CNN Model with Color-Specific Convolutions"""
    inputs = tf.keras.Input(shape=(64, 64, 3))
    
    channel1 = inputs[:, :, :, 0:1]  # First selected channel (e.g., 7)
    channel2 = inputs[:, :, :, 1:2]  # Second selected channel (e.g., 3)
    channel3 = inputs[:, :, :, 2:3]  # Third selected channel (e.g., 2)
    
    red_conv = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(channel1)
    red_pool = tf.keras.layers.MaxPooling2D(2,2)(red_conv)
    
    green_conv = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(channel2)
    green_pool = tf.keras.layers.MaxPooling2D(2,2)(green_conv)
    
    blue_conv = tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same')(channel3)
    blue_pool = tf.keras.layers.MaxPooling2D(2,2)(blue_conv)
    
    combined = tf.keras.layers.Concatenate()([red_pool, green_pool, blue_pool])
    
    conv1 = tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same')(combined)
    pool1 = tf.keras.layers.MaxPooling2D(2,2)(conv1)
    
    conv2 = tf.keras.layers.Conv2D(128, (3,3), activation='relu', padding='same')
# Epoch 72/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.1819e-06 - val_accuracy: 0.9267 - val_loss: 0.6941
# Epoch 73/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 9.7805e-07 - val_accuracy: 0.9276 - val_loss: 0.7002
# Epoch 74/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 8.2319e-07 - val_accuracy: 0.9263 - val_loss: 0.7076
# Epoch 75/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 6.7841e-07 - val_accuracy: 0.9270 - val_loss: 0.7127
# Epoch 76/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 5.5955e-07 - val_accuracy: 0.9265 - val_loss: 0.7219
# Epoch 77/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 4.8179e-07 - val_accuracy: 0.9263 - val_loss: 0.7251
# Epoch 78/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 4.1101e-07 - val_accuracy: 0.9269 - val_loss: 0.7339
# Epoch 79/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 3.5478e-07 - val_accuracy: 0.9274 - val_loss: 0.7388
# Epoch 80/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 3.1194e-07 - val_accuracy: 0.9265 - val_loss: 0.7497
# Epoch 81/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 2.4711e-07 - val_accuracy: 0.9267 - val_loss: 0.7527
# Epoch 82/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 2.1469e-07 - val_accuracy: 0.9259 - val_loss: 0.7622
# Epoch 83/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.7394e-07 - val_accuracy: 0.9259 - val_loss: 0.7698
# Epoch 84/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.5127e-07 - val_accuracy: 0.9261 - val_loss: 0.7776
# Epoch 85/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.3926e-07 - val_accuracy: 0.9263 - val_loss: 0.7837
# Epoch 86/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.1538e-07 - val_accuracy: 0.9263 - val_loss: 0.7918
# Epoch 87/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 9.3370e-08 - val_accuracy: 0.9257 - val_loss: 0.7918
# Epoch 88/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 7.7388e-08 - val_accuracy: 0.9259 - val_loss: 0.8028
# Epoch 89/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9594 - loss: 0.1764 - val_accuracy: 0.8737 - val_loss: 0.4297
# Epoch 90/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9648 - loss: 0.0993 - val_accuracy: 0.9117 - val_loss: 0.3873
# Epoch 91/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9963 - loss: 0.0153 - val_accuracy: 0.9120 - val_loss: 0.4428
# Epoch 92/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9996 - loss: 0.0041 - val_accuracy: 0.9048 - val_loss: 0.5347
# Epoch 93/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9992 - loss: 0.0042 - val_accuracy: 0.9202 - val_loss: 0.4779
# Epoch 94/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 5.7972e-04 - val_accuracy: 0.9198 - val_loss: 0.4947
# Epoch 95/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 2.7834e-04 - val_accuracy: 0.9207 - val_loss: 0.5040
# Epoch 96/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.8232e-04 - val_accuracy: 0.9202 - val_loss: 0.5150
# Epoch 97/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.3581e-04 - val_accuracy: 0.9200 - val_loss: 0.5233
# Epoch 98/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 1.0668e-04 - val_accuracy: 0.9207 - val_loss: 0.5285
# Epoch 99/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 8.6519e-05 - val_accuracy: 0.9215 - val_loss: 0.5335
# Epoch 100/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 7.0737e-05 - val_accuracy: 0.9222 - val_loss: 0.5417
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#
# Class                Accuracy
# AnnualCrop           0.91333
# Forest               0.97167
# HerbaceousVegetation 0.86833
# Highway              0.87000
# Industrial           0.96000
# Pasture              0.85500
# PermanentCrop        0.81600
# Residential          0.96667
# River                0.96800
# SeaLake              0.99833
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#           AnnualCrop    0.92256   0.91333   0.91792       600
#               Forest    0.97167   0.97167   0.97167       600
# HerbaceousVegetation    0.83494   0.86833   0.85131       600
#              Highway    0.90062   0.87000   0.88505       500
#           Industrial    0.94118   0.96000   0.95050       500
#              Pasture    0.87245   0.85500   0.86364       400
#        PermanentCrop    0.82258   0.81600   0.81928       500
#          Residential    0.95710   0.96667   0.96186       600
#                River    0.97778   0.96800   0.97286       500
#              SeaLake    0.99833   0.99833   0.99833       600
#
#             accuracy                        0.92222      5400
#            macro avg    0.91992   0.91873   0.91924      5400
#         weighted avg    0.92237   0.92222   0.92221      5400

# %% [markdown]
# **PROPOSED SE BASED SWIR-NIR-RED MODEL**

# %%
import os
import numpy as np
import tensorflow as tf
import rasterio
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# --- Parameters ---
data_dir = "/kaggle/input/all-band-eurosat/tif"
img_size = (64, 64)
selected_channels = [12, 7, 3]
batch_size = 64
epochs = 100

# --- Load Data ---
def load_tif_images(base_dir, img_size=(64, 64), selected_channels=[12, 7, 3]):
    images, labels = [], []
    class_names = sorted([d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))])
    
    for label in class_names:
        class_dir = os.path.join(base_dir, label)
        for fname in os.listdir(class_dir):
            if fname.endswith(".tif"):
                path = os.path.join(class_dir, fname)
                with rasterio.open(path) as src:
                    img = src.read(selected_channels)  # (3, H, W)
                    img = np.moveaxis(img, 0, -1)      # (H, W, 3)
                    img = img.astype(np.float32) / 255.0
                    img = tf.image.resize(img, img_size).numpy()
                    images.append(img)
                    labels.append(label)

    return np.array(images), np.array(labels), class_names

X, y, class_names = load_tif_images(data_dir, img_size, selected_channels)

# --- Encode Labels ---
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_onehot = tf.keras.utils.to_categorical(y_encoded)

# --- Split ---
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, stratify=y_encoded, random_state=42)

# --- TF Datasets ---
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1000).batch(batch_size)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size)

# --- SE Block ---
def se_block(input_tensor, reduction=8):
    filters = input_tensor.shape[-1]
    se = tf.keras.layers.GlobalAveragePooling2D()(input_tensor)
    se = tf.keras.layers.Dense(filters // reduction, activation='relu')(se)
    se = tf.keras.layers.Dense(filters, activation='sigmoid')(se)
    se = tf.keras.layers.Reshape((1, 1, filters))(se)
    return tf.keras.layers.Multiply()([input_tensor, se])

# --- Model ---
def create_color_specific_model(num_classes):
    inputs = tf.keras.Input(shape=(64, 64, 3))
    
    channel1 = inputs[:, :, :, 0:1]
    channel2 = inputs[:, :, :, 1:2]
    channel3 = inputs[:, :, :, 2:3]
    
    red_conv = tf.keras.layers.Conv2D(24, (3,3), activation='relu', padding='same')(channel1)
    red_se = se_block(red_conv)
    red_pool = tf.keras.layers.MaxPooling2D(2,2)(red_se)
    
    green_conv = tf.keras.layers.Conv2D(24, (3,3), activation='relu', padding='same')(channel2)
    green_se = se_block(green_conv)
    green_pool = tf.keras.layers.MaxPooling2D(2,2)(green_se)
    
    blue_conv = tf.keras.layers.Conv2D(24, (3,3), activation='relu', padding='same')(channel3)
    blue_se = se_block(blue_conv)
    blue_pool = tf.keras.layers.MaxPooling2D(2,2)(blue_se)
    
    combined = tf.keras.layers.Concatenate()([red_pool, green_pool, blue_pool])
    
    conv1 = tf.keras.layers.Conv2D(48, (3,3), activation='relu', padding='same')(combined)
    conv1_se = se_block(conv1)
    pool1 = tf.keras.layers.MaxPooling2D(2,2)(conv1_se)
    
    conv2 = tf.keras.layers.Conv2D(96, (3,3), activation='relu', padding='same')(pool1)
    conv2_se = se_block(conv2)
    pool2 = tf.keras.layers.MaxPooling2D(2,2)(conv2_se)
    
    flatten = tf.keras.layers.Flatten()(pool2)
    dense1 = tf.keras.layers.Dense(192, activation='relu')(flatten)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(dense1)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.AdamW(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# --- Train ---
model = create_color_specific_model(num_classes=len(class_names))
model.summary()
model.fit(train_ds, validation_data=test_ds, epochs=epochs)

# --- Evaluation ---
y_pred_probs = model.predict(test_ds)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(np.vstack([y for _, y in test_ds]), axis=1)

cm = confusion_matrix(y_true, y_pred)
per_class_acc = cm.diagonal() / cm.sum(axis=1)

print(f"\n{'Class':<20} {'Accuracy':<10}")
for i, label in enumerate(class_names):
    print(f"{label:<20} {per_class_acc[i]:.5f}")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=5))
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8             │ (None, 64, 64, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_34 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_35 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_36 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_58 (Conv2D)        │ (None, 64, 64, 24)     │            240 │ get_item_34[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_59 (Conv2D)        │ (None, 64, 64, 24)     │            240 │ get_item_35[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_60 (Conv2D)        │ (None, 64, 64, 24)     │            240 │ get_item_36[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 24)             │              0 │ conv2d_58[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 24)             │              0 │ conv2d_59[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 24)             │              0 │ conv2d_60[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_58 (Dense)          │ (None, 3)              │             75 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_60 (Dense)          │ (None, 3)              │             75 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_62 (Dense)          │ (None, 3)              │             75 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_59 (Dense)          │ (None, 24)             │             96 │ dense_58[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_61 (Dense)          │ (None, 24)             │             96 │ dense_60[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_63 (Dense)          │ (None, 24)             │             96 │ dense_62[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_20 (Reshape)      │ (None, 1, 1, 24)       │              0 │ dense_59[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_21 (Reshape)      │ (None, 1, 1, 24)       │              0 │ dense_61[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_22 (Reshape)      │ (None, 1, 1, 24)       │              0 │ dense_63[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_20 (Multiply)    │ (None, 64, 64, 24)     │              0 │ conv2d_58[0][0],       │
# │                           │                        │                │ reshape_20[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_21 (Multiply)    │ (None, 64, 64, 24)     │              0 │ conv2d_59[0][0],       │
# │                           │                        │                │ reshape_21[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_22 (Multiply)    │ (None, 64, 64, 24)     │              0 │ conv2d_60[0][0],       │
# │                           │                        │                │ reshape_22[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_53          │ (None, 32, 32, 24)     │              0 │ multiply_20[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_54          │ (None, 32, 32, 24)     │              0 │ multiply_21[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_55          │ (None, 32, 32, 24)     │              0 │ multiply_22[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 32, 32, 72)     │              0 │ max_pooling2d_53[0][0… │
# │ (Concatenate)             │                        │                │ max_pooling2d_54[0][0… │
# │                           │                        │                │ max_pooling2d_55[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_61 (Conv2D)        │ (None, 32, 32, 48)     │         31,152 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 48)             │              0 │ conv2d_61[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_64 (Dense)          │ (None, 6)              │            294 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_65 (Dense)          │ (None, 48)             │            336 │ dense_64[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_23 (Reshape)      │ (None, 1, 1, 48)       │              0 │ dense_65[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_23 (Multiply)    │ (None, 32, 32, 48)     │              0 │ conv2d_61[0][0],       │
# │                           │                        │                │ reshape_23[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d
# Epoch 74/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 3.5666e-07 - val_accuracy: 0.9233 - val_loss: 0.6965
# Epoch 75/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.9607e-07 - val_accuracy: 0.9231 - val_loss: 0.7025
# Epoch 76/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.3193e-07 - val_accuracy: 0.9237 - val_loss: 0.7109
# Epoch 77/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.9874e-07 - val_accuracy: 0.9237 - val_loss: 0.7183
# Epoch 78/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.5808e-07 - val_accuracy: 0.9239 - val_loss: 0.7254
# Epoch 79/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.3303e-07 - val_accuracy: 0.9237 - val_loss: 0.7338
# Epoch 80/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.2084e-07 - val_accuracy: 0.9237 - val_loss: 0.7420
# Epoch 81/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 9.7362e-08 - val_accuracy: 0.9235 - val_loss: 0.7499
# Epoch 82/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 8.1417e-08 - val_accuracy: 0.9231 - val_loss: 0.7582
# Epoch 83/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 7.2969e-08 - val_accuracy: 0.9230 - val_loss: 0.7671
# Epoch 84/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 5.5896e-08 - val_accuracy: 0.9226 - val_loss: 0.7733
# Epoch 85/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 4.8020e-08 - val_accuracy: 0.9230 - val_loss: 0.7812
# Epoch 86/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 3.9763e-08 - val_accuracy: 0.9230 - val_loss: 0.7878
# Epoch 87/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 3.3777e-08 - val_accuracy: 0.9231 - val_loss: 0.7962
# Epoch 88/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.7503e-08 - val_accuracy: 0.9235 - val_loss: 0.8030
# Epoch 89/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.4645e-08 - val_accuracy: 0.9237 - val_loss: 0.8106
# Epoch 90/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.0263e-08 - val_accuracy: 0.9243 - val_loss: 0.8198
# Epoch 91/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.6554e-08 - val_accuracy: 0.9241 - val_loss: 0.8272
# Epoch 92/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.4792e-08 - val_accuracy: 0.9235 - val_loss: 0.8332
# Epoch 93/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.3383e-08 - val_accuracy: 0.9239 - val_loss: 0.8556
# Epoch 94/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.5143e-08 - val_accuracy: 0.9241 - val_loss: 0.8501
# Epoch 95/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 9.4685e-09 - val_accuracy: 0.9235 - val_loss: 0.8575
# Epoch 96/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 7.2615e-09 - val_accuracy: 0.9241 - val_loss: 0.8645
# Epoch 97/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 6.0492e-09 - val_accuracy: 0.9244 - val_loss: 0.8696
# Epoch 98/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 5.6843e-09 - val_accuracy: 0.9237 - val_loss: 0.8726
# Epoch 99/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 5.2995e-09 - val_accuracy: 0.9239 - val_loss: 0.8818
# Epoch 100/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 4.3406e-09 - val_accuracy: 0.9239 - val_loss: 0.8830
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#
# Class                Accuracy
# AnnualCrop           0.91667
# Forest               0.98333
# HerbaceousVegetation 0.84000
# Highway              0.86200
# Industrial           0.97000
# Pasture              0.86250
# PermanentCrop        0.83000
# Residential          0.97500
# River                0.96800
# SeaLake              1.00000
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#           AnnualCrop    0.89869   0.91667   0.90759       600
#               Forest    0.96721   0.98333   0.97521       600
# HerbaceousVegetation    0.86301   0.84000   0.85135       600
#              Highway    0.93696   0.86200   0.89792       500
#           Industrial    0.94542   0.97000   0.95755       500
#              Pasture    0.87342   0.86250   0.86792       400
#        PermanentCrop    0.81055   0.83000   0.82016       500
#          Residential    0.96376   0.97500   0.96935       600
#                River    0.96032   0.96800   0.96414       500
#              SeaLake    0.99502   1.00000   0.99751       600
#
#             accuracy                        0.92389      5400
#            macro avg    0.92144   0.92075   0.92087      5400
#         weighted avg    0.92382   0.92389   0.92364      5400

# %% [markdown]
# **PROSED--NDVI-NDBI-NDWI MODEL**

# %%
import os
import numpy as np
import tensorflow as tf
import rasterio
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# ----------- Parameters -----------
data_dir = "/kaggle/input/all-band-eurosat/tif"
img_size = (64, 64)
selected_channels = [7, 3, 2]  # NIR, Green, Blue
batch_size = 64
epochs = 100

# ----------- Load Data with NDVI, NDBI, NDWI -----------
def load_tif_images(base_dir, img_size=(64, 64), selected_channels=[7, 3, 2]):
    images, labels = [], []
    class_names = sorted([d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))])
    
    for label in class_names:
        class_dir = os.path.join(base_dir, label)
        for fname in os.listdir(class_dir):
            if fname.endswith(".tif"):
                path = os.path.join(class_dir, fname)
                with rasterio.open(path) as src:
                    full_img = src.read()  # shape: (13, H, W)
                    
                    # Normalize
                    full_img = full_img.astype(np.float32) / 255.0
                    
                    # Get selected bands
                    img = full_img[selected_channels]  # shape: (3, H, W)
                    img = np.moveaxis(img, 0, -1)      # (H, W, 3)
                    
                    # Extract bands for index calculation
                    nir = full_img[7]    # Band 8 (NIR)
                    red = full_img[3]    # Band 4
                    green = full_img[2]  # Band 3
                    swir = full_img[10]  # Band 11
                    
                    # Resize all bands to match img_size
                    nir = tf.image.resize(nir[..., np.newaxis], img_size).numpy().squeeze()
                    red = tf.image.resize(red[..., np.newaxis], img_size).numpy().squeeze()
                    green = tf.image.resize(green[..., np.newaxis], img_size).numpy().squeeze()
                    swir = tf.image.resize(swir[..., np.newaxis], img_size).numpy().squeeze()
                    img = tf.image.resize(img, img_size).numpy()
                    
                    def safe_index(a, b):
                        return (a - b) / (a + b + 1e-6)
                    
                    ndvi = safe_index(nir, red)
                    ndbi = safe_index(swir, nir)
                    ndwi = safe_index(green, nir)
                    
                    # Stack indices as additional channels
                    indices = np.stack([ndvi, ndbi, ndwi], axis=-1)
                    
                    img = np.concatenate([img, indices], axis=-1)  # shape: (H, W, 6)
                    images.append(img)
                    labels.append(label)

    return np.array(images), np.array(labels), class_names

X, y, class_names = load_tif_images(data_dir, img_size, selected_channels)

# ----------- Encode Labels -----------
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_onehot = tf.keras.utils.to_categorical(y_encoded)

# ----------- Train-Test Split -----------
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, stratify=y_encoded, random_state=42)

# ----------- Dataset API -----------
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1000).batch(batch_size)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size)

# ----------- Updated CNN Model -----------
def create_model_with_indices(num_classes):
    inputs = tf.keras.Input(shape=(64, 64, 6))  # 3 bands + 3 indices
    
    # Split input into bands and indices
    ch1 = inputs[:, :, :, 0:1]  # NIR (band 7)
    ch2 = inputs[:, :, :, 1:2]  # GREEN (band 3)
    ch3 = inputs[:, :, :, 2:3]  # BLUE (band 2)
    ndvi = inputs[:, :, :, 3:4]
    ndbi = inputs[:, :, :, 4:5]
    ndwi = inputs[:, :, :, 5:6]

    def conv_branch(x):
        x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
        return tf.keras.layers.MaxPooling2D(2, 2)(x)

    branches = [conv_branch(ch) for ch in [ch1, ch2, ch3, ndvi, ndbi, ndwi]]
    combined = tf.keras.layers.Concatenate()(branches)

    x = tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same')(combined)
    x = tf.keras.layers.MaxPooling2D(2,2)(x)
    x = tf.keras.layers.Conv2D(128, (3,3), activation='relu', padding='same')(x)
    x = tf.keras.layers.MaxPooling2D(2,2)(x)
    
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.AdamW(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# ----------- Train Model -----------
model = create_model_with_indices(num_classes=len(class_names))
model.summary()
model.fit(train_ds, validation_data=test_ds, epochs=epochs)

# ----------- Evaluation -----------
y_pred_probs = model.predict(test_ds)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(np.vstack([y for _, y in test_ds]), axis=1)

cm = confusion_matrix(y_true, y_pred)
per_class_acc = cm.diagonal() / cm.sum(axis=1)

print(f"\n{'Class':<20} {'Accuracy':<10}")
for i, label in enumerate(class_names):
    print(f"{label:<20} {per_class_acc[i]:.5f}")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=5))
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 64, 64, 6)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_13 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_14 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_15 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_16 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_17 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_18 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 64, 64, 32)     │            320 │ get_item_13[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 64, 64, 32)     │            320 │ get_item_14[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 64, 64, 32)     │            320 │ get_item_15[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 64, 64, 32)     │            320 │ get_item_16[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 64, 64, 32)     │            320 │ get_item_17[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 64, 64, 32)     │            320 │ get_item_18[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_15          │ (None, 32, 32, 32)     │              0 │ conv2d_15[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_16          │ (None, 32, 32, 32)     │              0 │ conv2d_16[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_17          │ (None, 32, 32, 32)     │              0 │ conv2d_17[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_18          │ (None, 32, 32, 32)     │              0 │ conv2d_18[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_19          │ (None, 32, 32, 32)     │              0 │ conv2d_19[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_20          │ (None, 32, 32, 32)     │              0 │ conv2d_20[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 32, 32, 192)    │              0 │ max_pooling2d_15[0][0… │
# │ (Concatenate)             │                        │                │ max_pooling2d_16[0][0… │
# │                           │                        │                │ max_pooling2d_17[0][0… │
# │                           │                        │                │ max_pooling2d_18[0][0… │
# │                           │                        │                │ max_pooling2d_19[0][0… │
# │                           │                        │                │ max_pooling2d_20[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None,
# Epoch 75/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 1.1097e-05 - val_accuracy: 0.9335 - val_loss: 0.5733
# Epoch 76/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 9.4497e-06 - val_accuracy: 0.9331 - val_loss: 0.5743
# Epoch 77/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 8.0828e-06 - val_accuracy: 0.9333 - val_loss: 0.5758
# Epoch 78/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 7.2614e-06 - val_accuracy: 0.9331 - val_loss: 0.5770
# Epoch 79/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 5.9886e-06 - val_accuracy: 0.9335 - val_loss: 0.5787
# Epoch 80/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 5.4171e-06 - val_accuracy: 0.9331 - val_loss: 0.5805
# Epoch 81/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 4.7322e-06 - val_accuracy: 0.9337 - val_loss: 0.5825
# Epoch 82/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 4.0467e-06 - val_accuracy: 0.9337 - val_loss: 0.5847
# Epoch 83/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 3.4747e-06 - val_accuracy: 0.9339 - val_loss: 0.5870
# Epoch 84/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 2.9529e-06 - val_accuracy: 0.9343 - val_loss: 0.5899
# Epoch 85/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 2.5626e-06 - val_accuracy: 0.9343 - val_loss: 0.5929
# Epoch 86/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 2.1854e-06 - val_accuracy: 0.9344 - val_loss: 0.5964
# Epoch 87/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 1.8951e-06 - val_accuracy: 0.9346 - val_loss: 0.5994
# Epoch 88/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 1.6534e-06 - val_accuracy: 0.9344 - val_loss: 0.6025
# Epoch 89/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 1.4040e-06 - val_accuracy: 0.9354 - val_loss: 0.6061
# Epoch 90/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 1.1876e-06 - val_accuracy: 0.9356 - val_loss: 0.6086
# Epoch 91/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 1.0283e-06 - val_accuracy: 0.9350 - val_loss: 0.6117
# Epoch 92/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 9.1345e-07 - val_accuracy: 0.9354 - val_loss: 0.6146
# Epoch 93/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 7.7835e-07 - val_accuracy: 0.9354 - val_loss: 0.6179
# Epoch 94/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 6.5691e-07 - val_accuracy: 0.9357 - val_loss: 0.6206
# Epoch 95/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 5.7350e-07 - val_accuracy: 0.9356 - val_loss: 0.6236
# Epoch 96/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 4.9189e-07 - val_accuracy: 0.9356 - val_loss: 0.6267
# Epoch 97/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 4.1133e-07 - val_accuracy: 0.9361 - val_loss: 0.6303
# Epoch 98/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 3.6236e-07 - val_accuracy: 0.9369 - val_loss: 0.6332
# Epoch 99/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 3.0516e-07 - val_accuracy: 0.9369 - val_loss: 0.6360
# Epoch 100/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 1.0000 - loss: 2.5896e-07 - val_accuracy: 0.9369 - val_loss: 0.6401
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#
# Class                Accuracy
# AnnualCrop           0.93000
# Forest               0.98667
# HerbaceousVegetation 0.88500
# Highway              0.89000
# Industrial           0.96200
# Pasture              0.85750
# PermanentCrop        0.86800
# Residential          0.98333
# River                0.97600
# SeaLake              0.99500
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#           AnnualCrop    0.91028   0.93000   0.92003       600
#               Forest    0.97851   0.98667   0.98257       600
# HerbaceousVegetation    0.88060   0.88500   0.88279       600
#              Highway    0.93684   0.89000   0.91282       500
#           Industrial    0.95626   0.96200   0.95912       500
#              Pasture    0.90263   0.85750   0.87949       400
#        PermanentCrop    0.84932   0.86800   0.85856       500
#          Residential    0.96248   0.98333   0.97279       600
#                River    0.97796   0.97600   0.97698       500
#              SeaLake    0.99833   0.99500   0.99666       600
#
#             accuracy                        0.93685      5400
#            macro avg    0.93532   0.93335   0.93418      5400
#         weighted avg    0.93692   0.93685   0.93675      5400

# %% [markdown]
# **PROPOSED SE BASED NDBI-NIR-RED**

# %%
import os
import numpy as np
import tensorflow as tf
import rasterio
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# --- Load and Preprocess ---
def load_index_images(base_dir, img_size=(64, 64)):
    images, labels = [], []
    class_names = sorted([d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))])
    
    for label in class_names:
        class_dir = os.path.join(base_dir, label)
        for fname in os.listdir(class_dir):
            if fname.endswith(".tif"):
                path = os.path.join(class_dir, fname)
                with rasterio.open(path) as src:
                    B3 = src.read(3).astype(np.float32)
                    B4 = src.read(4).astype(np.float32)
                    B5 = src.read(5).astype(np.float32)
                    B6 = src.read(6).astype(np.float32)

                    NDVI = (B5 - B4) / (B5 + B4 + 1e-5)
                    NDBI = (B6 - B5) / (B6 + B5 + 1e-5)
                    NDWI = (B3 - B5) / (B3 + B5 + 1e-5)

                    index_img = np.stack([NDBI, NDVI, NDWI], axis=-1)
                    index_img = np.nan_to_num(index_img)
                    index_img = tf.image.resize(index_img, img_size).numpy()
                    index_img = np.clip(index_img, -1, 1)
                    images.append(index_img)
                    labels.append(label)

    return np.array(images), np.array(labels), class_names

data_dir = "/kaggle/input/all-band-eurosat/tif"
X, y, class_names = load_index_images(data_dir)

# --- Label Encoding ---
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_onehot = tf.keras.utils.to_categorical(y_encoded)

# --- Train-Test Split ---
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, stratify=y_encoded, random_state=42)
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1000).batch(64)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(64)

# --- SE Block ---
def se_block(input_tensor, reduction=8):
    filters = input_tensor.shape[-1]
    se = tf.keras.layers.GlobalAveragePooling2D()(input_tensor)
    se = tf.keras.layers.Dense(filters // reduction, activation='relu')(se)
    se = tf.keras.layers.Dense(filters, activation='sigmoid')(se)
    se = tf.keras.layers.Reshape((1, 1, filters))(se)
    return tf.keras.layers.Multiply()([input_tensor, se])

# --- Model Definition (~1.5M Params) ---
def create_index_model(num_classes):
    inputs = tf.keras.Input(shape=(64, 64, 3))
    
    ch1 = tf.keras.layers.Conv2D(24, 3, activation='relu', padding='same')(inputs[:, :, :, 0:1])
    ch1 = se_block(ch1)
    ch1 = tf.keras.layers.MaxPooling2D()(ch1)
    
    ch2 = tf.keras.layers.Conv2D(24, 3, activation='relu', padding='same')(inputs[:, :, :, 1:2])
    ch2 = se_block(ch2)
    ch2 = tf.keras.layers.MaxPooling2D()(ch2)
    
    ch3 = tf.keras.layers.Conv2D(24, 3, activation='relu', padding='same')(inputs[:, :, :, 2:2+1])
    ch3 = se_block(ch3)
    ch3 = tf.keras.layers.MaxPooling2D()(ch3)
    
    merged = tf.keras.layers.Concatenate()([ch1, ch2, ch3])
    
    x = tf.keras.layers.Conv2D(48, 3, activation='relu', padding='same')(merged)
    x = se_block(x)
    x = tf.keras.layers.MaxPooling2D()(x)
    
    x = tf.keras.layers.Conv2D(96, 3, activation='relu', padding='same')(x)
    x = se_block(x)
    x = tf.keras.layers.MaxPooling2D()(x)
    
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(192, activation='relu')(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    
    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer=tf.keras.optimizers.AdamW(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# --- Train ---
model = create_index_model(num_classes=len(class_names))
model.summary()
model.fit(train_ds, validation_data=test_ds, epochs=100)

# --- Evaluation ---
y_pred_probs = model.predict(test_ds)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(np.vstack([y for _, y in test_ds]), axis=1)

cm = confusion_matrix(y_true, y_pred)
per_class_acc = cm.diagonal() / cm.sum(axis=1)

print(f"\n{'Class':<20} {'Accuracy':<10}")
for i, label in enumerate(class_names):
    print(f"{label:<20} {per_class_acc[i]:.5f}")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, digits=5))
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_9             │ (None, 64, 64, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_37 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_38 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_39 (GetItem)     │ (None, 64, 64, 1)      │              0 │ input_layer_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_63 (Conv2D)        │ (None, 64, 64, 24)     │            240 │ get_item_37[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_64 (Conv2D)        │ (None, 64, 64, 24)     │            240 │ get_item_38[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_65 (Conv2D)        │ (None, 64, 64, 24)     │            240 │ get_item_39[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 24)             │              0 │ conv2d_63[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 24)             │              0 │ conv2d_64[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 24)             │              0 │ conv2d_65[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_70 (Dense)          │ (None, 3)              │             75 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_72 (Dense)          │ (None, 3)              │             75 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_74 (Dense)          │ (None, 3)              │             75 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_71 (Dense)          │ (None, 24)             │             96 │ dense_70[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_73 (Dense)          │ (None, 24)             │             96 │ dense_72[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_75 (Dense)          │ (None, 24)             │             96 │ dense_74[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_25 (Reshape)      │ (None, 1, 1, 24)       │              0 │ dense_71[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_26 (Reshape)      │ (None, 1, 1, 24)       │              0 │ dense_73[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_27 (Reshape)      │ (None, 1, 1, 24)       │              0 │ dense_75[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_25 (Multiply)    │ (None, 64, 64, 24)     │              0 │ conv2d_63[0][0],       │
# │                           │                        │                │ reshape_25[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_26 (Multiply)    │ (None, 64, 64, 24)     │              0 │ conv2d_64[0][0],       │
# │                           │                        │                │ reshape_26[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_27 (Multiply)    │ (None, 64, 64, 24)     │              0 │ conv2d_65[0][0],       │
# │                           │                        │                │ reshape_27[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_58          │ (None, 32, 32, 24)     │              0 │ multiply_25[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_59          │ (None, 32, 32, 24)     │              0 │ multiply_26[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_60          │ (None, 32, 32, 24)     │              0 │ multiply_27[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 32, 32, 72)     │              0 │ max_pooling2d_58[0][0… │
# │ (Concatenate)             │                        │                │ max_pooling2d_59[0][0… │
# │                           │                        │                │ max_pooling2d_60[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_66 (Conv2D)        │ (None, 32, 32, 48)     │         31,152 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 48)             │              0 │ conv2d_66[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_76 (Dense)          │ (None, 6)              │            294 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_77 (Dense)          │ (None, 48)             │            336 │ dense_76[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_28 (Reshape)      │ (None, 1, 1, 48)       │              0 │ dense_77[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_28 (Multiply)    │ (None, 32, 32, 48)     │              0 │ conv2d_66[0][0],       │
# │                           │                        │                │ reshape_28[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_61          │ (None, 16, 16, 48)     │              0 │ multiply_28[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_67 (Conv2D)        │ (None, 16, 16, 96)     │         41,568 │ max_pooling2d_61[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 96)             │              0 │ conv2d_67[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_78 (Dense)          │ (None, 12)             │          1,164 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_79 (Dense)          │ (None, 96)             │          1,248 │ dense_78[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_29 (Reshape)      │ (None, 1, 1, 96)       │              0 │ dense_79[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_29 (Multiply)    │ (None, 16, 16, 96)     │              0 │ conv2d_67[0][0],       │
# │                           │                        │                │ reshape_29[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_62          │ (None, 8, 8, 96)       │              0 │ multiply_29[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_9 (Flatten)       │ (None, 6144)           │              0 │ max_pooling2d_62[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_80 (Dense)          │ (None, 192)            │      1,179,840 │ flatten_9[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_81 (Dense)          │ (None, 10)             │          1,930 │ dense_80[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,258,765 (4.80 MB)
#  Trainable params: 1,258,765 (4.80 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.5606 - loss: 1.1884 - val_accuracy: 0.8111 - val_loss: 0.5377
# Epoch 2/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8217 - loss: 0.5087 - val_accuracy: 0.8222 - val_loss: 0.5129
# Epoch 3/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8605 - loss: 0.4062 - val_accuracy: 0.8620 - val_loss: 0.4032
# Epoch 4/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8856 - loss: 0.3384 - val_accuracy: 0.8915 - val_loss: 0.3264
# Epoch 5/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8895 - loss: 0.3158 - val_accuracy: 0.8952 - val_loss: 0.3061
# Epoch 6/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9080 - loss: 0.2729 - val_accuracy: 0.9050 - val_loss: 0.2767
# Epoch 7/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.
100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9967 - loss: 0.0102 - val_accuracy: 0.9237 - val_loss: 0.4786
# Epoch 76/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9986 - loss: 0.0069 - val_accuracy: 0.9359 - val_loss: 0.4028
# Epoch 77/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 3.8613e-04 - val_accuracy: 0.9376 - val_loss: 0.3972
# Epoch 78/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 9.3386e-05 - val_accuracy: 0.9385 - val_loss: 0.3985
# Epoch 79/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 7.0074e-05 - val_accuracy: 0.9383 - val_loss: 0.4019
# Epoch 80/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 6.0347e-05 - val_accuracy: 0.9393 - val_loss: 0.4058
# Epoch 81/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 4.4212e-05 - val_accuracy: 0.9394 - val_loss: 0.4092
# Epoch 82/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 1.0000 - loss: 3.6200e-05 - val_accuracy: 0.9394 - val_loss: 0.4127
# Epoch 83/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 3.2690e-05 - val_accuracy: 0.9398 - val_loss: 0.4164
# Epoch 84/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.5304e-05 - val_accuracy: 0.9396 - val_loss: 0.4205
# Epoch 85/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.1388e-05 - val_accuracy: 0.9394 - val_loss: 0.4250
# Epoch 86/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.7622e-05 - val_accuracy: 0.9394 - val_loss: 0.4287
# Epoch 87/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.4884e-05 - val_accuracy: 0.9394 - val_loss: 0.4340
# Epoch 88/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.2847e-05 - val_accuracy: 0.9398 - val_loss: 0.4378
# Epoch 89/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.0848e-05 - val_accuracy: 0.9396 - val_loss: 0.4431
# Epoch 90/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 9.1993e-06 - val_accuracy: 0.9404 - val_loss: 0.4475
# Epoch 91/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 7.9944e-06 - val_accuracy: 0.9398 - val_loss: 0.4536
# Epoch 92/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 6.4022e-06 - val_accuracy: 0.9404 - val_loss: 0.4583
# Epoch 93/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 5.2781e-06 - val_accuracy: 0.9409 - val_loss: 0.4624
# Epoch 94/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 4.4327e-06 - val_accuracy: 0.9409 - val_loss: 0.4679
# Epoch 95/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 3.6850e-06 - val_accuracy: 0.9407 - val_loss: 0.4743
# Epoch 96/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 3.1595e-06 - val_accuracy: 0.9413 - val_loss: 0.4792
# Epoch 97/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.6873e-06 - val_accuracy: 0.9411 - val_loss: 0.4857
# Epoch 98/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 2.1882e-06 - val_accuracy: 0.9413 - val_loss: 0.4912
# Epoch 99/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.8526e-06 - val_accuracy: 0.9419 - val_loss: 0.4963
# Epoch 100/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 1.0000 - loss: 1.5897e-06 - val_accuracy: 0.9420 - val_loss: 0.5052
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#
# Class                Accuracy
# AnnualCrop           0.91833
# Forest               0.98833
# HerbaceousVegetation 0.92333
# Highway              0.88600
# Industrial           0.97600
# Pasture              0.86750
# PermanentCrop        0.89800
# Residential          0.98000
# River                0.95200
# SeaLake              0.99667
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#           AnnualCrop    0.93867   0.91833   0.92839       600
#               Forest    0.96895   0.98833   0.97855       600
# HerbaceousVegetation    0.91874   0.92333   0.92103       600
#              Highway    0.93263   0.88600   0.90872       500
#           Industrial    0.96252   0.97600   0.96922       500
#              Pasture    0.86534   0.86750   0.86642       400
#        PermanentCrop    0.88212   0.89800   0.88999       500
#          Residential    0.95455   0.98000   0.96711       600
#                River    0.97541   0.95200   0.96356       500
#              SeaLake    0.99336   0.99667   0.99501       600
#
#             accuracy                        0.94204      5400
#            macro avg    0.93923   0.93862   0.93880      5400
#         weighted avg    0.94204   0.94204   0.94192      5400
